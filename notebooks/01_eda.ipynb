# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Data
df = pd.read_csv(r"D:\final_project\data\tabular_data\tabular data.csv")

print("Dataset Shape:", df.shape)
print("\nColumns:\n", df.columns)
print("\nFirst 5 Rows:\n", df.head())
print("\nMissing Values:\n", df.isnull().sum())


# Target Distribution

plt.figure()
df['outcome'].value_counts().plot(kind='bar', title="Disease Outcome Distribution")
plt.xlabel("Outcome")
plt.ylabel("Count")
plt.show()


# Numeric Feature Distribution

num_cols = df.select_dtypes(include=['int64','float64']).columns
df[num_cols].hist(figsize=(10,6))
plt.suptitle("Numeric Feature Distributions")
plt.show()


# Correlation Heatmap

numeric_df = df.select_dtypes(include=['int64','float64'])

plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# Dataset Shape: (1500, 13)
#
# Columns:
#  Index(['patient_id', 'age', 'gender', 'bmi', 'systolic_bp', 'diastolic_bp',
#        'heart_rate', 'cholesterol', 'blood_sugar', 'has_hypertension',
#        'has_diabetes', 'length_of_stay_days', 'outcome'],
#       dtype='object')
#
# First 5 Rows:
#     patient_id  age gender   bmi  systolic_bp  diastolic_bp  heart_rate  \
# 0           1   69      M  27.5          136           119          57
# 1           2   32      M  24.9          176            61         116
# 2           3   89    feM  24.7          119            79         118
# 3           4   78      M  19.0          114            79          99
# 4           5   38      M  30.0          117           118         112
#
#    cholesterol  blood_sugar  has_hypertension  has_diabetes  \
# 0          209           77                 0             0
# 1          290          176                 0             0
# 2          150          238                 0             0
# 3          214          200                 0             0
# 4          182          211                 1             1
#
#    length_of_stay_days     outcome
# 0                  0.6   Recovered
# 1                  4.3   Recovered
# 2                  7.6  Readmitted
# 3                  2.3   Recovered
# 4                 19.1   Recovered
#
# Missing Values:
#  patient_id             0
# age                    0
# gender                 0
# bmi                    0
# systolic_bp            0
# diastolic_bp           0
# heart_rate             0
# cholesterol            0
# blood_sugar            0
# has_hypertension       0
# has_diabetes           0
# length_of_stay_days    0
# outcome                0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['patient_id', 'age', 'gender', 'bmi', 'systolic_bp', 'diastolic_bp',
#        'heart_rate', 'cholesterol', 'blood_sugar', 'has_hypertension',
#        'has_diabetes', 'length_of_stay_days', 'outcome'],
#       dtype='object')
